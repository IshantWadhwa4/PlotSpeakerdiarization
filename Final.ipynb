# %%
# %run addButtons.ipynb
# Out:
# C:\Users\ishant\AppData\Local\Continuum\anaconda3\lib\site-packages\pydub\utils.py:165: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# C:\Users\ishant\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['show']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# Populating the interactive namespace from numpy and matplotlib
# ...
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# npm notice
# npm notice package: @jupyter-widgets/jupyterlab-manager@1.1.0
# npm notice === Tarball Contents ===
# npm notice 2.3kB  package.json
# npm notice 1.5kB  LICENSE
# npm notice 1.9kB  README.md
# npm notice 277B   lib/index.d.ts
# npm notice 380B   lib/index.js
# ...

# %%
# %run visualization.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
from functools import partial

# %%
# some handy functions to use along widgets
from IPython.display import display, Markdown, clear_output
# widget packages
import ipywidgets as widgets

# %%
def show(audioFileData):
    singleFileData = audioFileData
    df = singleFileAnalysis(singleFileData)    
    showGraph2(df)

# %%
class Counter:
    def __init__(self, initial=0):
        self.value = initial
    def increment(self, amount=1):
        self.value += amount
        return self.value
    def getValue(self):
        return self.value

# %%
def on_button_clicked(counter, w):      
        # what happens when we press the button
        clear_output()
        #print(counter.value , AudioFileData.shape[0])
        if(counter.value < AudioFileData.shape[0]):
            show(AudioFileData.loc[counter.value])
        else:
            print('No more data')
        counter.increment()
        display(w)
        
            
counter = Counter()
w = widgets.Button(description='Next')
w.on_click(partial(on_button_clicked, counter))
display(w)
# Out:
# 2
# 1
# 2
# 0
# 1
#     <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <title>Simple Test</title>
#     </head>
#
#     <body>
#     <audio controls="controls" style="width:600px" >
#       <source src="files/./chunk/ES2010d1chunk0.wav" type="audio/wav" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>
# 1
# 0
# 1
# 4
# 3
# 0
# 4
# 3
#     <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <title>Simple Test</title>
#     </head>
#
#     <body>
#     <audio controls="controls" style="width:600px" >
#       <source src="files/./chunk/ES2010d1chunk1.wav" type="audio/wav" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>
# 3
# 2
# 0
# 3
#     <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <title>Simple Test</title>
#     </head>
#
#     <body>
# ...
